# %%
import pandas as pd
import numpy as np
from datetime import datetime
from pytz import timezone
import yfinance as yf
from tinvest import SyncClient
import websocket
from scipy import stats
import datetime as dt
from pandas_datareader import data as wb
from datetime import datetime
from pandas_datareader._utils import RemoteDataError

# %%
f = open('../tokens.txt')
token = f.read()
token = token[:-1]

# %%
def toFixed(numObj, digits=0):
    return f"{numObj:.{digits}f}"

# %%
def api_connect(token):
    client = SyncClient(token, use_sandbox=False)
    return client

# %%
async def main():
    client = AsyncClient(token, use_sandbox=False)
    await client.get_accounts()

# %%
def usd_cur(client):
    response = client.get_market_orderbook(figi='BBG0013HGFT4', depth=1)  # tinvest.PortfolioResponse
    return response.payload.last_price

# %%
def get_id(client):
    response = client.get_accounts()
    broker_id = iis_id = 0
    for acc in response.payload.accounts:
        if acc.broker_account_type.value == 'Tinkoff':
            broker_id = acc.broker_account_id
        if acc.broker_account_type == 'TinkoffIis':
            iis_id = acc.broker_account_id
    return broker_id, iis_id

# %%
def get_portfolio(client,id, usd):
    response = client.get_portfolio(broker_account_id=id)
    df = pd.DataFrame()
    for pos in response.payload.positions:
        cur = 1
        if pos.average_position_price.currency == 'RUB':
            cur = usd
        name = pos.name
        n_shares = pos.balance
        ticker = pos.ticker
        isin = pos.isin
        figi = pos.figi
        currency = pos.average_position_price.currency.value
        price = float(toFixed((pos.average_position_price.value + pos.expected_yield.value/pos.balance)/cur, 1))
        position = float(toFixed((pos.average_position_price.value * pos.balance + pos.expected_yield.value)/cur, 1))
        average_price = float(toFixed(pos.average_position_price.value/cur, 1))
        result = float(toFixed(pos.expected_yield.value/cur,1))
        df = df.append(pd.Series([ticker, figi, isin, currency, price, position,n_shares, average_price, result]),ignore_index=True)
    df.columns = ['ticker', 'figi', 'isin', 'currency', 'price', 'position', 'n_shares','average', 'result']
    df['share'] = [float(toFixed(pos*100/sum(df['position']),1)) for pos in df['position']]
    df = df.sort_values(by=['share'], ascending=False)
    df = df.reset_index()
    df = df.drop(['index'], axis=1)
    return df

# %%
def get_operations(client,start, end, id, usd):
    operations = pd.DataFrame()
    response = client.get_operations(from_=start.isoformat(), to=end.isoformat(), broker_account_id=id)
    for pos in response.payload.operations:
        cur = 1
        if pos.currency == 'RUB':
            cur = usd
        if pos.operation_type.value in ('Buy', 'Sell'):
            quantity = pos.quantity
            quantity_ex = pos.quantity_executed
            price = pos.price
        else:
            quantity = 0
            price = 0
            quantity_ex = 0
        operations = operations.append(pd.Series([pos.date.date(),pos.figi, pos.operation_type.value, float(quantity_ex),float(quantity), float(price/cur), float(pos.payment/cur)]),ignore_index=True)
    operations.columns = ['date', 'figi', 'type', 'quantity_ex', 'quantity', 'price', 'result']
    return operations

# %%
def get_market_search(client,oper):
    stocks = pd.DataFrame()
    for fig in oper.index:
        response = client.get_market_search_by_figi(fig)
        stocks = stocks.append(pd.Series([response.payload.name, response.payload.ticker, fig]),ignore_index=True)
    stocks.columns = ['name', 'ticker','figi']
    return stocks

# %%
def get_stock_data(tickers,delim=1000000):
    stockdata = pd.DataFrame()
    t = yf.Ticker('USDCNY=X')
    cny = float(t.info['previousClose'])
    t = yf.Ticker('USDC-RUB')
    rub = float(t.info['previousClose'])
    for tick in tickers:
        t = yf.Ticker(tick)
        val = 1
        try:
            if t.info['country'] == 'China':
                val = cny
            if t.info['country'] == 'Netherlands':
                val = rub
            if len(t.earnings.values) == 0:
                revenue = 0
                earnings = 0
            else:
                rev = t.earnings['Revenue']
                earn = t.earnings['Earnings']
                earnings = float(toFixed(earn.values[len(earn)-1]/(delim*val),1))
                revenue = float(toFixed(rev.values[len(rev)-1]/(delim*val),1))
            if t.info['forwardPE'] is None:
                fpe = t.info['forwardPE']
            else:
                fpe = float(toFixed(t.info['forwardPE'],1))
            if t.info['beta'] is None:
                beta = t.info['beta']
            else:
                beta = float(toFixed(t.info['beta'],1))
            if t.info['shortPercentOfFloat'] is None:
                short = t.info['shortPercentOfFloat']
            else:
                short = float(toFixed(t.info['shortPercentOfFloat']*100,1))
            if revenue == 0.:
                ps = float('inf')
            else:
                ps = float(toFixed(t.info['marketCap'] / (revenue*delim),1))
            day200 = float(toFixed(t.info['twoHundredDayAverage'],1))
            day50 = float(toFixed(t.info['fiftyDayAverage'],1))
            avg10dayvolume = float(toFixed(t.info['averageDailyVolume10Day']/delim,1))
            stockdata = stockdata.append(pd.Series([tick,revenue,earnings, fpe, ps, beta, short,day200,day50,avg10dayvolume]),ignore_index=True)
        except (IndexError, ImportError, KeyError) as e:
            continue
    stockdata.columns = ['ticker', 'revenue', 'earnings', 'forward PE', 'PS', 'beta', 'short percent','avg200','avg50','avgvolume10']
    return stockdata

# %%
def get_categories(stockdata):
    categories = list()
    for s in stockdata.iloc:
        if ((s.revenue > 10000) and (s.earnings > 1000)):
            categories.append('A')
        elif ((s.revenue > 2000) and(s.earnings > 100)):
            categories.append('B')
        elif (s.revenue > abs(s.earnings)):
            categories.append('C')
        else:
            categories.append('D')
    return categories

# %%
def data_for_income_compare(ticks, date='2020-08-05'):
    data = pd.DataFrame()
    res = pd.DataFrame()
    for ticker in ticks.index:
        try:
            data[ticker]=wb.DataReader(ticker,data_source='yahoo',start=date)['Adj Close']
            for t in ticks.columns:
                if t in data.index:
                    data[ticker].loc[t] *= int(ticks[t].loc[ticker])
        except RemoteDataError:
            continue
        except KeyError:
            continue
        except ValueError:
            continue
    return data.transpose().fillna(0)

# %%
def data_for_compare(ticks):
    data = pd.DataFrame()
    for ticker in ticks.index:
        data[ticker]=wb.DataReader(ticker,data_source='yahoo',start='2000-01-01')['Adj Close']
        data[ticker] *= int(ticks.loc[ticker].values)
        data[ticker] = data[ticker].fillna(0)
        data[ticker] = data[ticker].fillna(data[ticker].dropna()[0])
    data['portfolio'] = data.sum(axis=1)
    data = data['portfolio']
    return data

# %%
def compare(change, start):
    result = list()
    result.append(start)
    for i in range(1, len(change)):
         result.append(result[i-1]*(1+change[i]))
    return pd.Series(result)

# %%
def Sharpe_ratio(df,column='portfolio'):
    data = df
    data['Norm return'] = data[column] / data.iloc[0][column]
    cumulative_return = 100 * ( data[column] [-1 ] / data [column] [ 0 ] -1)
    data['Daily Return'] = data[column].pct_change(1)
    Sharpe_Ratio = data['Daily Return'].mean() / data['Daily Return'].std()
    A_Sharpe_Ratio = (252**0.5) * Sharpe_Ratio
    return A_Sharpe_Ratio

# %%
def combine_portfolio_result(buysells, mod, date="2020-08-05", period=365, payment=7608):
    idx = pd.date_range(date, periods=period, freq="D")
    bs = pd.DataFrame()
    for fig in set(buysells['figi']):
        bs_list = pd.Series([fig]+[0]*len(list(idx)))
        bs = bs.append(bs_list, ignore_index=True)
    bs = bs.set_index(0)
    bs.columns = idx
    for fig in buysells['figi']:
        for dat in buysells[buysells['figi'] == fig]['date']:
            if mod == 'result':
                bs[dat][fig] = -sum(buysells[(buysells['figi'] == fig) & (buysells['date'] == dat)][mod])
            else:
                bs[dat][fig] = sum(buysells[(buysells['figi'] == fig) & (buysells['date'] == dat)][mod])
    bs = bs.cumsum(axis=1)
    return bs

# %%
client = api_connect(token)

# %%
broker, iis = get_id(client)

# %%
usd = usd_cur(client)

# %%
df = get_portfolio(client,iis, usd)

# %% [markdown]
# Текущее состояние портфеля

# %%
df
# Out:
#           ticker          figi          isin currency  price  position  \
# 0           COIN  BBG00ZGF7771  US19260Q1076      USD  223.5    1341.0
# 1           BIDU  BBG000QXWHD1  US0567521085      USD  187.9    1127.4
# 2             SQ  BBG0018SLC07  US8522341036      USD  219.4     877.8
# 3           BABA  BBG006G2JVL2  US01609W1027      USD  211.7     635.2
# 4           TDOC  BBG0019T5SG0  US87918A1051      USD  154.7     618.9
# 5            AYX  BBG000BGZT72  US02156B1035      USD   82.3     576.0
# 6           FSLY  BBG004NLQHL0  US31188V1008      USD   54.2     379.3
# 7             JD  BBG005YHY0Q7  US47215P1066      USD   71.2     355.8
# 8           PLTR  BBG000N7QR55  US69608A1088      USD   24.6     245.9
# 9           EDIT  BBG005MX5GZ2  US28106W1036      USD   37.3     149.2
# 10          BLUE  BBG000QGWY50  US09609G1004      USD   33.9     135.8
# 11          NVTA  BBG005DJFD43  US46185L1035      USD   31.1     124.5
# 12          SRPT  BBG000BCJ161  US8036071004      USD   86.2      86.2
# 13          ATRA  BBG005Q3MQY4  US0465131078      USD   14.4      72.2
# 14          MAIL  BBG00178PGX3  US5603172082      RUB   22.7      45.4
# 15  USD000UTSTOM  BBG0013HGFT4          None      RUB    1.0       7.6
# 16  EUR_RUB__TOM  BBG0013HJJ31          None      RUB    1.2       1.1
#
#    n_shares  average  result  share
# 0         6    293.3  -418.6   19.8
# 1         6    259.9  -432.2   16.6
# 2         4    233.1   -54.5   12.9
# 3         3    222.9   -33.5    9.4
# 4         4    190.7  -143.8    9.1
# 5         7     91.1   -61.7    8.5
# 6         7     60.0   -40.9    5.6
# 7         5     77.0   -29.0    5.2
# 8      10.0     24.7    -1.5    3.6
# 9         4     52.3   -60.0    2.2
# 10        4     41.1   -28.7    2.0
# 11        4     39.6   -34.0    1.8
# 12        1     91.9    -5.6    1.3
# 13        5     17.4   -14.7    1.1
# 14        2     24.2    -3.0    0.7
# 15     7.63      1.0    -0.1    0.1
# 16     0.87      1.2    -0.0    0.0

# %% [markdown]
# Догрузим эмитенты, которыми мы владели в прошлом

# %%
start = datetime(2020, 1, 1, 0, 0, 0, tzinfo=timezone('Europe/Moscow'))
end = datetime.now(tz=timezone('Europe/Moscow'))
operations = get_operations(client,start, end, iis, usd)

# %%
oper = operations.groupby(['figi']).sum()

# %%
stock = get_market_search(client, oper)

# %%
stocks = stock.set_index('figi').join(oper)

# %%
tickers = stocks['ticker'].values

# %%
stockdata = get_stock_data(tickers)

# %% [markdown]
# Также мы выгрузили различные полезные показатели.
# По неизвестной причине перестаои подтягиваться данные по прибыли и выручке.
# Раньше все работало.

# %%
stockdata
# Out:
#    ticker  revenue  earnings forward PE   PS  beta short percent  avg200  \
# 0    AAPL      0.0       0.0       23.8  inf   1.2           0.7   128.0
# 1    SRPT      0.0       0.0      -22.1  inf   1.5          11.8    99.0
# 2     AYX      0.0       0.0      191.3  inf   0.7           6.2    99.7
# 3    ZYXI      0.0       0.0       19.9  inf   0.8          19.4    15.6
# 4    FISV      0.0       0.0       17.2  inf   0.9           2.1   116.0
# 5     IBM      0.0       0.0       12.6  inf   1.2           2.8   131.3
# 6     NOK      0.0       0.0       18.1  inf   0.6          None     4.3
# 7     MRK      0.0       0.0       11.4  inf   0.4           0.7    74.4
# 8    EXEL      0.0       0.0       24.2  inf   1.1           4.1    22.5
# 9    INTC      0.0       0.0       12.6  inf   0.6           1.5    57.5
# 10   BIIB      0.0       0.0       19.1  inf   0.4           2.3   270.8
# 11   VRTX      0.0       0.0       15.3  inf   0.7           1.6   219.3
# 12   CSCO      0.0       0.0       16.1  inf   0.9           0.9    48.4
# 13   QDEL      0.0       0.0       12.4  inf  -0.0          13.8   161.9
# 14   REGN      0.0       0.0       13.3  inf   0.2           2.4   492.6
# 15   CLDR      0.0       0.0       31.6  inf   1.1           7.7    13.8
# 16   ALXN      0.0       0.0       12.8  inf   1.3           3.8   156.8
# 17   NBIX      0.0       0.0       24.7  inf   0.8           5.5    99.5
# 18   QLYS      0.0       0.0       35.1  inf   0.6          15.8   106.7
# 19   IONS      0.0       0.0      -22.2  inf   1.1           9.1    49.2
# 20   CHKP      0.0       0.0       16.7  inf   0.6           6.0   120.3
# 21     FB      0.0       0.0       21.8  inf   1.3           1.1   287.6
# 22   PLTR      0.0       0.0       None  inf  None           4.2    25.4
# 23     GM      0.0       0.0        9.2  inf   1.4           1.2    53.1
# 24   BLUE      0.0       0.0       -3.3  inf   1.7           9.6    36.4
# 25   BIDU      0.0       0.0       16.3  inf   1.0          None   222.0
# 26     SQ      0.0       0.0      104.0  inf   2.4           8.0   229.6
# 27   TDOC      0.0       0.0     -164.7  inf   0.2          11.9   200.1
# 28   PSTG      0.0       0.0       36.7  inf   1.4           6.4    21.8
# 29   UBER      0.0       0.0      -75.8  inf   1.6           4.1    54.0
# 30     PD      0.0       0.0     -212.8  inf   1.3          15.5    42.6
# 31   FSLY      0.0       0.0     -217.5  inf   1.1          23.4    76.3
# 32   NVTA      0.0       0.0      -14.3  inf   1.9          16.2    41.5
# 33    TCS      0.0       0.0       14.1  inf   1.3          19.9    13.7
# 34   GTHX      0.0       0.0       -6.3  inf   2.2          15.0    22.0
# 35   EDIT      0.0       0.0      -10.0  inf   1.9          18.4    49.3
# 36   ATRA      0.0       0.0       -4.2  inf   2.4          17.4    17.3
# 37     JD      0.0       0.0       27.8  inf   0.8          None    84.3
# 38   BABA      0.0       0.0       17.5  inf   0.8          None   239.8
# 39   YNDX      0.0       0.0       37.4  inf   1.3           2.3    66.4
# 40   WORK      0.0       0.0     -211.8  inf  None           8.4    42.0
# 41   NTLA      0.0       0.0      -29.3  inf   2.0          11.7    66.0
# 42   FIVE      0.0       0.0       34.4  inf   1.3           5.7   184.3
# 43   BTAI      0.0       0.0      -10.3  inf   1.1          20.3    43.7
# 44   ALLO      0.0       0.0      -10.0  inf   1.1           9.2    31.3
# 45   TECH      0.0       0.0       59.0  inf   1.1           1.3   372.8
# 46   TBIO      0.0       0.0      -57.8  inf   0.9          12.9    21.3
#
#     avg50  avgvolume10
# 0   127.7         67.2
# 1    75.7          1.2
# 2    78.9          0.9
# 3    15.0          0.2
# 4   115.8          4.8
# 5   145.1          4.0
# 6     5.0         55.3
# 7    74.0         14.3
# 8    23.8          1.4
# 9    56.8         21.4
# 10  292.2          6.3
# 11  212.6          3.3
# 12   52.7         16.0
# 13  114.1          1.2
# 14  503.5          0.8
# 15   13.3          9.0
# 16  173.7          1.7
# 17   94.8          0.7
# 18   99.9          0.2
# 19   38.1          1.9
# 20  118.3          0.7
# 21  319.9         14.1
# 22   22.1         48.1
# 23   58.3         17.6
# 24   30.6          1.6
# 25  195.5          4.3
# 26  221.9          7.1
# 27  153.3          2.3
# 28   19.0          3.0
# 29   50.5         14.3
# 30   38.9          1.9
# 31   51.3          6.2
# 32   30.1          3.0
# 33   13.5          0.6
# 34   21.3          1.3
# 35   34.8          1.1
# 36   14.0          0.7
# 37   73.9          9.4
# 38  219.6         10.9
# 39   65.6          1.1
# 40   42.6          4.2
# 41   72.5          1.1
# 42  188.4          0.8
# 43   33.5          0.3
# 44   28.0          1.3
# 45  418.0          0.2
# 46   19.4          0.6

# %% [markdown]
# Здесь я делю акции по категориям.
# А: надежные компании с высокой прибылью с капитализацией более 10 млрд
# В: прибыльные компании средней капитализации
# С: убыточные компании с положительной выручкой
# D: убыточные компании с околонулевой выручкой, стартапы на раннем этапе
#
# Разделение по категориям в данный момент не работает по той же причине :(

# %%
categories = pd.Series(get_categories(stockdata))

# %%
stockdata = pd.concat([stockdata,categories], axis=1)

# %%
stockdata.columns = ['ticker', 'revenue', 'earnings', 'forward PE', 'PS', 'beta', 'short percent','avg200','avg50','avgvolume10','category']

# %%
portfolio = df.join(stockdata.set_index('ticker'), on='ticker', how='right')

# %%
for cat in ['A','B','C','D']:
    s = sum(portfolio[portfolio['category'] == cat]['share'].dropna())
    print(cat, s)
# Out:
# A 0
# B 0
# C 0
# D 79.30000000000001

# %%
s = stocks.set_index('ticker').join(portfolio.set_index('ticker'), lsuffix='_oper', rsuffix='_port', on='ticker', how='right')

# %%
s['position'] = s['position'].fillna(0)

# %%
s['result'] = s['result_oper'] + s['position']

# %%
s = s.drop(['isin','result_port','result_oper', 'figi', 'currency','price_oper','quantity_ex','quantity'],axis=1)

# %%
s['share'] = s['share'].fillna(0)
s['average'] = s['average'].fillna(0)
s['n_shares'] = s['n_shares'].fillna(0)

# %%
for tick in s[s['price_port'].isna()].index:
    t = yf.Ticker(tick)
#     s.loc[tick] = {'price': t.info['open']}
    s.loc[tick] = s.loc[tick].fillna(t.info['open'])

# %% [markdown]
# Итоговый результат

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(s.sort_values(by=['result'], ascending=False))
# Out:
#                                          name  price_port  position n_shares  \
# ticker
# SQ                                     Square     219.400     877.8        4
# TCS           TCS Group (Tinkoff Bank holder)      13.690       0.0        0
# INTC                        Intel Corporation      57.470       0.0        0
# CLDR                             Cloudera Inc      15.810       0.0        0
# GTHX                      G1 Therapeutics Inc      21.920       0.0        0
# PD                              Pagerduty Inc      39.820       0.0        0
# PSTG                         Pure Storage Inc      19.200       0.0        0
# ALXN                  Alexion Pharmaceuticals     181.950       0.0        0
# BIIB                                   Biogen     423.330       0.0        0
# NTLA                Intellia Therapeutics Inc      85.000       0.0        0
# WORK                   Slack Technologies Inc      44.310       0.0        0
# ZYXI                                Zynex Inc      16.120       0.0        0
# TECH                          Тинькофф NASDAQ     438.220       0.0        0
# ALLO                Allogene Therapeutics Inc      25.910       0.0        0
# FB                                   Facebook     332.580       0.0        0
# NBIX               Neurocrine Biosciences Inc     100.420       0.0        0
# IONS                Ionis Pharmaceuticals Inc      38.280       0.0        0
# PLTR                Palantir Technologies Inc      24.600     245.9     10.0
# TBIO                  Тинькофф NASDAQ Biotech      21.830       0.0        0
# CSCO                                    Cisco      55.190       0.0        0
# FISV                                   Fiserv     110.393       0.0        0
# BTAI                     BioXcel Therapeutics      38.070       0.0        0
# UBER                                     Uber      50.030       0.0        0
# YNDX                                   Yandex      69.110       0.0        0
# IBM                                       IBM     150.430       0.0        0
# QDEL                              Quidel Corp     115.180       0.0        0
# EXEL                             Exelixis Inc      22.850       0.0        0
# MRK                                     Merck      76.710       0.0        0
# VRTX                   Vertex Pharmaceuticals     194.040       0.0        0
# FIVE                       ГДР X5 RetailGroup     186.740       0.0        0
# SRPT                 Sarepta Therapeutics Inc      86.200      86.2        1
# GM                             General Motors      61.360       0.0        0
# CHKP    Check Point Software Technologies Ltd     120.500       0.0        0
# QLYS                               Qualys Inc     103.360       0.0        0
# FSLY                               Fastly Inc      54.200     379.3        7
# NOK                                     Nokia       5.480       0.0        0
# AAPL                                    Apple     126.530       0.0        0
# ATRA                Atara Biotherapeutics Inc      14.400      72.2        5
# JD                                     JD.com      71.200     355.8        5
# BLUE                         Bluebird Bio Inc      33.900     135.8        4
# NVTA                             Invitae Corp      31.100     124.5        4
# BABA                                  Alibaba     211.700     635.2        3
# REGN                Regeneron Pharmaceuticals     529.280       0.0        0
# EDIT                      Editas Medicine Inc      37.300     149.2        4
# AYX                               Alteryx Inc      82.300     576.0        7
# BIDU                                    Baidu     187.900    1127.4        6
# TDOC                       Teladoc Health Inc     154.700     618.9        4
#
#         average  share  revenue  earnings forward PE   PS   beta  \
# ticker
# SQ        233.1   12.9      0.0       0.0      104.0  inf    2.4
# TCS         0.0    0.0      0.0       0.0       14.1  inf    1.3
# INTC        0.0    0.0      0.0       0.0       12.6  inf    0.6
# CLDR        0.0    0.0      0.0       0.0       31.6  inf    1.1
# GTHX        0.0    0.0      0.0       0.0       -6.3  inf    2.2
# PD          0.0    0.0      0.0       0.0     -212.8  inf    1.3
# PSTG        0.0    0.0      0.0       0.0       36.7  inf    1.4
# ALXN        0.0    0.0      0.0       0.0       12.8  inf    1.3
# BIIB        0.0    0.0      0.0       0.0       19.1  inf    0.4
# NTLA        0.0    0.0      0.0       0.0      -29.3  inf    2.0
# WORK        0.0    0.0      0.0       0.0     -211.8  inf  44.31
# ZYXI        0.0    0.0      0.0       0.0       19.9  inf    0.8
# TECH        0.0    0.0      0.0       0.0       59.0  inf    1.1
# ALLO        0.0    0.0      0.0       0.0      -10.0  inf    1.1
# FB          0.0    0.0      0.0       0.0       21.8  inf    1.3
# NBIX        0.0    0.0      0.0       0.0       24.7  inf    0.8
# IONS        0.0    0.0      0.0       0.0      -22.2  inf    1.1
# PLTR       24.7    3.6      0.0       0.0       None  inf   None
# TBIO        0.0    0.0      0.0       0.0      -57.8  inf    0.9
# CSCO        0.0    0.0      0.0       0.0       16.1  inf    0.9
# FISV        0.0    0.0      0.0       0.0       17.2  inf    0.9
# BTAI        0.0    0.0      0.0       0.0      -10.3  inf    1.1
# UBER        0.0    0.0      0.0       0.0      -75.8  inf    1.6
# YNDX        0.0    0.0      0.0       0.0       37.4  inf    1.3
# IBM         0.0    0.0      0.0       0.0       12.6  inf    1.2
# QDEL        0.0    0.0      0.0       0.0       12.4  inf   -0.0
# EXEL        0.0    0.0      0.0       0.0       24.2  inf    1.1
# MRK         0.0    0.0      0.0       0.0       11.4  inf    0.4
# VRTX        0.0    0.0      0.0       0.0       15.3  inf    0.7
# FIVE        0.0    0.0      0.0       0.0       34.4  inf    1.3
# SRPT       91.9    1.3      0.0       0.0      -22.1  inf    1.5
# GM          0.0    0.0      0.0       0.0        9.2  inf    1.4
# CHKP        0.0    0.0      0.0       0.0       16.7  inf    0.6
# QLYS        0.0    0.0      0.0       0.0       35.1  inf    0.6
# FSLY       60.0    5.6      0.0       0.0     -217.5  inf    1.1
# NOK         0.0    0.0      0.0       0.0       18.1  inf    0.6
# AAPL        0.0    0.0      0.0       0.0       23.8  inf    1.2
# ATRA       17.4    1.1      0.0       0.0       -4.2  inf    2.4
# JD         77.0    5.2      0.0       0.0       27.8  inf    0.8
# BLUE       41.1    2.0      0.0       0.0       -3.3  inf    1.7
# NVTA       39.6    1.8      0.0       0.0      -14.3  inf    1.9
# BABA      222.9    9.4      0.0       0.0       17.5  inf    0.8
# REGN        0.0    0.0      0.0       0.0       13.3  inf    0.2
# EDIT       52.3    2.2      0.0       0.0      -10.0  inf    1.9
# AYX        91.1    8.5      0.0       0.0      191.3  inf    0.7
# BIDU      259.9   16.6      0.0       0.0       16.3  inf    1.0
# TDOC      190.7    9.1      0.0       0.0     -164.7  inf    0.2
#
#        short percent  avg200  avg50  avgvolume10 category      result
# ticker
# SQ               8.0   229.6  221.9          7.1        D  191.760000
# TCS             19.9    13.7   13.5          0.6        D  116.811464
# INTC             1.5    57.5   56.8         21.4        D   89.500000
# CLDR             7.7    13.8   13.3          9.0        D   69.740000
# GTHX            15.0    22.0   21.3          1.3        D   64.070000
# PD              15.5    42.6   38.9          1.9        D   61.480000
# PSTG             6.4    21.8   19.0          3.0        D   47.530000
# ALXN             3.8   156.8  173.7          1.7        D   44.690000
# BIIB             2.3   270.8  292.2          6.3        D   39.980000
# NTLA            11.7    66.0   72.5          1.1        D   29.150000
# WORK             8.4    42.0   42.6          4.2        D   26.290000
# ZYXI            19.4    15.6   15.0          0.2        D   20.670000
# TECH             1.3   372.8  418.0          0.2        D   16.530000
# ALLO             9.2    31.3   28.0          1.3        D   13.030000
# FB               1.1   287.6  319.9         14.1        D    9.460000
# NBIX             5.5    99.5   94.8          0.7        D    7.160000
# IONS             9.1    49.2   38.1          1.9        D    7.090000
# PLTR             4.2    25.4   22.1         48.1        D    6.190000
# TBIO            12.9    21.3   19.4          0.6        D    4.400000
# CSCO             0.9    48.4   52.7         16.0        D    3.520000
# FISV             2.1   116.0  115.8          4.8        D    2.760000
# BTAI            20.3    43.7   33.5          0.3        D    1.510000
# UBER             4.1    54.0   50.5         14.3        D    0.000000
# YNDX             2.3    66.4   65.6          1.1        D   -0.790933
# IBM              2.8   131.3  145.1          4.0        D   -0.880000
# QDEL            13.8   161.9  114.1          1.2        D   -1.420000
# EXEL             4.1    22.5   23.8          1.4        D   -1.960000
# MRK              0.7    74.4   74.0         14.3        D   -2.100000
# VRTX             1.6   219.3  212.6          3.3        D   -4.770000
# FIVE             5.7   184.3  188.4          0.8        D   -5.304034
# SRPT            11.8    99.0   75.7          1.2        D   -5.950000
# GM               1.2    53.1   58.3         17.6        D   -6.080000
# CHKP             6.0   120.3  118.3          0.7        D  -10.990000
# QLYS            15.8   106.7   99.9          0.2        D  -11.360000
# FSLY            23.4    76.3   51.3          6.2        D  -12.990000
# NOK             5.48     4.3    5.0         55.3        D  -13.180000
# AAPL             0.7   128.0  127.7         67.2        D  -13.710000
# ATRA            17.4    17.3   14.0          0.7        D  -14.880000
# JD              None    84.3   73.9          9.4        D  -24.870000
# BLUE             9.6    36.4   30.6          1.6        D  -29.000000
# NVTA            16.2    41.5   30.1          3.0        D  -29.360000
# BABA            None   239.8  219.6         10.9        D  -34.250000
# REGN             2.4   492.6  503.5          0.8        D  -43.190000
# EDIT            18.4    49.3   34.8          1.1        D  -60.150000
# AYX              6.2    99.7   78.9          0.9        D -155.250000
# BIDU            None   222.0  195.5          4.3        D -314.460000
# TDOC            11.9   200.1  153.3          2.3        D -331.940000

# %%
df = df[((df['ticker'] != 'USD000UTSTOM') & (df['ticker'] != 'EUR_RUB__TOM'))]

# %%
ticks = df[['ticker', 'n_shares']]
ticks = ticks.set_index('ticker')
ticks = ticks.sort_values(by=['n_shares'])

# %% [markdown]
# Здесь я пытаюсь сравнить свой портфель с индексом.
# Формирования результата своего портфеля немного специфичное.
# Т.к. некоторые компании в моем портфеле недавно вышли на биржу, а рассматривать хочется период хотя бы полтора года, я заменил null на стоимость акции в первый день торгов.
# Позже придумаю, как сделать все умнее.

# %%
data = data_for_compare(ticks)

# %%
t = yf.Ticker('SPY')
spy = t.history(period='max')
spy_roll = spy['Close'].rolling(200).mean().dropna()
spy_roll_50 = spy['Close'].rolling(50).mean().dropna()
spy_curve = spy.join(spy_roll, rsuffix='_roll200')[['Close','Close_roll200']]
spy_curve = spy_curve.join(spy_roll_50, rsuffix='_roll50')[['Close','Close_roll200','Close_roll50']]

# %%
spy_norm = spy_curve['Close'] / spy_curve['Close'].max()
data_norm = data/data.max()
spy_close = pd.DataFrame(spy_curve['Close'])
comp = spy_close.join(data).dropna()
comp['Close_per'] = comp['Close'].pct_change()

# %%
comp = comp[5060:]

# %%
cmp = compare(comp['Close_per'].values, comp['portfolio'][0])

# %%
comp = comp.join(pd.DataFrame(cmp).set_index(comp.index))

# %%
comp = comp.drop(['Close', 'Close_per'],axis=1)
comp.columns = ['portfolio','sp500']

# %%
comp.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Высокая волатильность выбранных мною акций позволяла мне обгонять S&P в прошлом году, однако на дистанции результат скорее всего получится хуже.

# %%
data = pd.DataFrame(data)

# %% [markdown]
# Считаю коэффициент Шарпа для своего портфеля и для S&P 500

# %%
print('Мой портфельчик: ', Sharpe_ratio(data, 'portfolio'))
print('S&P: ', Sharpe_ratio(spy_close, 'Close'))
# Out:
# Мой портфельчик:  0.45360228080479964
# S&P:  0.618492254740014

# %% [markdown]
# При этом по Шарпу S&P лучше

# %% [markdown]
# Давно хотел посмотреть динамику прибыли своего портфеля. Это оказалось не так просто сделать.

# %%
buys = operations[(operations['type'] == 'Buy') & (operations['quantity_ex'] != 0) & (operations['figi'] != 'BBG0013HGFT4')]

# %%
sells = operations[(operations['type']=='Sell') & (operations['quantity_ex'] != 0) & (operations['figi'] != 'BBG0013HGFT4')]

# %%
buysells = pd.concat([buys,sells], axis=0, ignore_index=True).sort_values(by='date')

# %%
for i in buysells.index:
    if buysells['type'][i] == 'Sell':
        buysells['quantity_ex'][i] = -buysells['quantity_ex'][i]
# Out:
# <ipython-input-906-34dd2eb5e0fa>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   buysells['quantity_ex'][i] = -buysells['quantity_ex'][i]

# %%
buysells['date'] = buysells['date'].astype('<M8[ns]')

# %%
portfolio_result = combine_portfolio_result(buysells,'result')

# %%
portfolio_quantity = combine_portfolio_result(buysells,'quantity_ex')

# %%
pp = stock.set_index('figi').join(portfolio_result)    
pq = stock.set_index('figi').join(portfolio_quantity)
pp = pp.set_index('ticker').drop('name',axis=1)
pq = pq.set_index('ticker').drop('name',axis=1)

# %% [markdown]
# Приходится убирать некоторые тикеры, которых нет на yahoo finance.

# %%
pp = pp.drop(['UPRO','TUSD','BMW@DE','USD000UTSTOM', 'EUR_RUB__TOM',
       'MAIL','GAZP', 'VTBR', 'LKOH','GMKN', 'SBERP', 'CHMF', 'NVTK','SNGSP', 'MTSS','FIVE','TECH', 'TGLD',
       'TBIO', 'TIPO', 'TSPX'], axis=0)
pq = pq.drop(['UPRO','TUSD','BMW@DE','USD000UTSTOM', 'EUR_RUB__TOM',
       'MAIL','GAZP', 'VTBR', 'LKOH','GMKN', 'SBERP', 'CHMF', 'NVTK','SNGSP', 'MTSS','FIVE','TECH', 'TGLD',
       'TBIO', 'TIPO', 'TSPX'], axis=0)

# %%
pp = pp.dropna()
pq = pq.dropna()

# %%
pq_res = data_for_income_compare(pq)

# %%
for col in pp.columns:
    if col not in pq_res.columns:
        pp = pp.drop(col, axis = 1)

# %%
pp_res = pq_res - pp

# %%
d = list()
income = pd.DataFrame()
for t in pp_res.columns:
    d.append(sum(pp_res[t]))
income['result'] = pd.Series(d)
income.index = pp_res.columns

# %%
income.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# В моменте убыток превышал 20%. Это произошло из-за того, что основные покупки в мой портфель пришлись на зиму 2020, когда акции роста были уже достаточно дороги. Причем я начал активно выкупать падение, чем и загнал свой портфель в достаточно большой минус.

# %% [markdown]
# В дальнейшем хочу сравнить, что бы было, если бы я вместо акций покупал S&P.
# Понятно, что результат бы был лучше. Интересно, насколько лучше.
